# %%
from GridWorld import GridWorld
from collections import defaultdict

# %%
env = GridWorld()

# %%
env

# %%
print(env.height,env.width,env.shape)
# Out:
# 3 4 (3, 4)

# %%
env.actions()
# Out:
# [0, 1, 2, 3]

# %%
# yieldのおかげで途中に処理を追加できる
for state in env.states():
    print(state)
# Out:
# (0, 0)
# (0, 1)
# (0, 2)
# (0, 3)
# (1, 0)
# (1, 1)
# (1, 2)
# (1, 3)
# (2, 0)
# (2, 1)
# (2, 2)
# (2, 3)

# %%
import numpy as np

V ={}
for state in env.states():
    V[state] = np.random.randn()

# %%
# 状態価値関数V
env.render_value_function(V)

# %%
V
# Out:
# {(0, 0): -0.25697135948113764,
#  (0, 1): -0.8682933217354633,
#  (0, 2): -1.2441937838162607,
#  (0, 3): -0.46114299140788023,
#  (1, 0): -1.268834257863649,
#  (1, 1): -1.9869418398203145,
#  (1, 2): 1.0398625456749107,
#  (1, 3): 0.06523651983931786,
#  (2, 0): 0.5340737309640505,
#  (2, 1): 2.3294667639570292,
#  (2, 2): -0.23246090700427624,
#  (2, 3): 1.254815384481781}

# %%
V
# Out:
# {(0, 0): -0.25697135948113764,
#  (0, 1): -0.8682933217354633,
#  (0, 2): -1.2441937838162607,
#  (0, 3): -0.46114299140788023,
#  (1, 0): -1.268834257863649,
#  (1, 1): -1.9869418398203145,
#  (1, 2): 1.0398625456749107,
#  (1, 3): 0.06523651983931786,
#  (2, 0): 0.5340737309640505,
#  (2, 1): 2.3294667639570292,
#  (2, 2): -0.23246090700427624,
#  (2, 3): 1.254815384481781}

# %%
# 方策

pi = defaultdict(lambda : {i : 0.25 for i in range(4)})

# %%
state = (0,1)
print(pi[state])
# Out:
# {0: 0.25, 1: 0.25, 2: 0.25, 3: 0.25}

# %%
print(pi)
# Out:
# defaultdict(<function <lambda> at 0x000001A5D88217E0>, {(0, 1): {0: 0.25, 1: 0.25, 2: 0.25, 3: 0.25}})
